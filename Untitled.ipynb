# %%
# Basic predictions
import pandas as pd
from IPython.display import display
tr = pd.read_csv('true_result.csv')

# %%
tr = tr.drop(['Unnamed: 0','Unnamed: 0.1','level_0','index','date'],1)

# %%
# Out:
#     home_team       away_team  home_score  away_score  \
# 0  Costa Rica          Panama           3           0
# 1      Mexico          Sweden           0           1
# 2  Costa Rica          Panama           0           0
# 3      France       Argentina           0           2
# 4        Iran  Korea Republic           1           1
#
#                      tournament         city   country  neutral  year_played  \
# 0                     UNCAF Cup  Tegucigalpa  Honduras     True         2009
# 1                      Friendly      Oakland       USA     True         2009
# 2                     UNCAF Cup  Tegucigalpa  Honduras     True         2009
# 3                      Friendly    Marseille    France    False         2009
# 4  FIFA World Cup qualification      Teheran      Iran    False         2009
#
#    PT_DIFF         ...         aw_GK_Diving_avg  aw_GK_Kicking_max  \
# 0        3         ...                 8.714286                 16
# ...
